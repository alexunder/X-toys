# %%
import urllib.request
import csv
import json

url = 'http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=1000&offset=0&name=&rows=1000&page=0&_=1539675850318'


Cookie = 'JSESSIONID=TVh7ys10DYfn8c29CWi62fg4xF0LfimxwbBtfHURakBAhcb1VOln!1660571454; UqZBpD3n3n2ZW104sQY@=v1DsaGSQ@@jQV; _gscu_2065735475=80925151vi0g0e97; _gscbrs_2065735475=1; _trs_uv=jnbev26f_365_7ltn; UqZBpD3n3n2FT00@=v1R8aGSQ@@SQC; _gscu_2145764248=39679145fbpzdl25; _gscbrs_2145764248=1; _gscs_2145764248=39679145ssq1pd25|pv:1; _gscs_2065735475=t396791452qnhsx25|pv:1; _trs_ua_s_1=jnbh7kw2_365_9fx6'

headers = { 'User-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.106 Safari/537.36',
            'Cookie': Cookie,
            'Connection': 'keep-alive',
            'Accept': 'application/json, text/javascript, */*; q=0.01',
            'Accept-Encoding': 'gzip, deflate',
            'Accept-Language': 'en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7,zh-TW;q=0.6,de;q=0.5',
            'Host': 'www.bjrbj.gov.cn',
            'Referer': 'http://www.bjrbj.gov.cn/integralpublic/settleperson/settlePersonTable/' }

base = 'http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&'

page_size = 100

limit_int = page_size
limit_str = 'limit=' + str(limit_int)

offset_str = '&offset='
offset_int = 0

name_str = '&name='


rows_int = page_size
rows_str = '&rows=' + str(rows_int)

pages_str = '&page='
pages_int = 0

tails = '&_=1539675850320'

total = 0

settlePeople = open('SettleDataAll.csv', 'w')
csvwriter = csv.writer(settlePeople)

csv_headers = ['id','Name','IdCard','Score','Unit']
csvwriter.writerow(csv_headers)

while True:
    url = base + limit_str + offset_str + str(offset_int) + name_str + rows_str + pages_str + str(pages_int) + tails
    print("url=" + url)
    req = urllib.request.Request(url, None, headers)
    response = urllib.request.urlopen(req)
    content = response.read()
    json_buffer = json.loads(content.decode('gbk', 'ignore'))
    
    #print(json_buffer['rows'])
    for i in json_buffer['rows']:
        data = [i['pxid'], i['name'], i['idCard'], i['score'], i['unit']]
        csvwriter.writerow(data)

    total = total + 1
    offset_int += page_size
    pages_int += page_size
    print("total pages=" + str(json_buffer['totalPages']))
    print("total=" + str(total))
    #totalp = json_buffer['totalPages']
    #print(str(type(json_buffer['totalPages'])))
    if total >= json_buffer['totalPages']:
        break

settlePeople.close()
# Out:
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=0&name=&rows=100&page=0&_=1539675850320
# total pages=61
# total=1
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=100&name=&rows=100&page=100&_=1539675850320
# total pages=61
# total=2
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=200&name=&rows=100&page=200&_=1539675850320
# total pages=61
# total=3
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=300&name=&rows=100&page=300&_=1539675850320
# total pages=61
# total=4
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=400&name=&rows=100&page=400&_=1539675850320
# total pages=61
# total=5
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=500&name=&rows=100&page=500&_=1539675850320
# total pages=61
# total=6
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=600&name=&rows=100&page=600&_=1539675850320
# total pages=61
# total=7
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=700&name=&rows=100&page=700&_=1539675850320
# total pages=61
# total=8
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=800&name=&rows=100&page=800&_=1539675850320
# total pages=61
# total=9
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=900&name=&rows=100&page=900&_=1539675850320
# total pages=61
# total=10
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=1000&name=&rows=100&page=1000&_=1539675850320
# total pages=61
# total=11
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=1100&name=&rows=100&page=1100&_=1539675850320
# total pages=61
# total=12
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=1200&name=&rows=100&page=1200&_=1539675850320
# total pages=61
# total=13
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=1300&name=&rows=100&page=1300&_=1539675850320
# total pages=61
# total=14
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=1400&name=&rows=100&page=1400&_=1539675850320
# total pages=61
# total=15
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=1500&name=&rows=100&page=1500&_=1539675850320
# total pages=61
# total=16
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=1600&name=&rows=100&page=1600&_=1539675850320
# total pages=61
# total=17
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=1700&name=&rows=100&page=1700&_=1539675850320
# total pages=61
# total=18
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=1800&name=&rows=100&page=1800&_=1539675850320
# total pages=61
# total=19
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=1900&name=&rows=100&page=1900&_=1539675850320
# total pages=61
# total=20
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=2000&name=&rows=100&page=2000&_=1539675850320
# total pages=61
# total=21
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=2100&name=&rows=100&page=2100&_=1539675850320
# total pages=61
# total=22
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=2200&name=&rows=100&page=2200&_=1539675850320
# total pages=61
# total=23
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=2300&name=&rows=100&page=2300&_=1539675850320
# total pages=61
# total=24
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=2400&name=&rows=100&page=2400&_=1539675850320
# total pages=61
# total=25
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=2500&name=&rows=100&page=2500&_=1539675850320
# total pages=61
# total=26
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=2600&name=&rows=100&page=2600&_=1539675850320
# total pages=61
# total=27
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=2700&name=&rows=100&page=2700&_=1539675850320
# total pages=61
# total=28
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=2800&name=&rows=100&page=2800&_=1539675850320
# total pages=61
# total=29
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=2900&name=&rows=100&page=2900&_=1539675850320
# total pages=61
# total=30
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=3000&name=&rows=100&page=3000&_=1539675850320
# total pages=61
# total=31
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=3100&name=&rows=100&page=3100&_=1539675850320
# total pages=61
# total=32
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=3200&name=&rows=100&page=3200&_=1539675850320
# total pages=61
# total=33
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=3300&name=&rows=100&page=3300&_=1539675850320
# total pages=61
# total=34
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=3400&name=&rows=100&page=3400&_=1539675850320
# total pages=61
# total=35
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=3500&name=&rows=100&page=3500&_=1539675850320
# total pages=61
# total=36
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=3600&name=&rows=100&page=3600&_=1539675850320
# total pages=61
# total=37
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=3700&name=&rows=100&page=3700&_=1539675850320
# total pages=61
# total=38
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=3800&name=&rows=100&page=3800&_=1539675850320
# total pages=61
# total=39
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=3900&name=&rows=100&page=3900&_=1539675850320
# total pages=61
# total=40
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=4000&name=&rows=100&page=4000&_=1539675850320
# total pages=61
# total=41
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=4100&name=&rows=100&page=4100&_=1539675850320
# total pages=61
# total=42
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=4200&name=&rows=100&page=4200&_=1539675850320
# total pages=61
# total=43
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=4300&name=&rows=100&page=4300&_=1539675850320
# total pages=61
# total=44
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=4400&name=&rows=100&page=4400&_=1539675850320
# total pages=61
# total=45
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=4500&name=&rows=100&page=4500&_=1539675850320
# total pages=61
# total=46
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=4600&name=&rows=100&page=4600&_=1539675850320
# total pages=61
# total=47
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=4700&name=&rows=100&page=4700&_=1539675850320
# total pages=61
# total=48
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=4800&name=&rows=100&page=4800&_=1539675850320
# total pages=61
# total=49
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=4900&name=&rows=100&page=4900&_=1539675850320
# total pages=61
# total=50
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=5000&name=&rows=100&page=5000&_=1539675850320
# total pages=61
# total=51
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=5100&name=&rows=100&page=5100&_=1539675850320
# total pages=61
# total=52
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=5200&name=&rows=100&page=5200&_=1539675850320
# total pages=61
# total=53
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=5300&name=&rows=100&page=5300&_=1539675850320
# total pages=61
# total=54
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=5400&name=&rows=100&page=5400&_=1539675850320
# total pages=61
# total=55
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=5500&name=&rows=100&page=5500&_=1539675850320
# total pages=61
# total=56
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=5600&name=&rows=100&page=5600&_=1539675850320
# total pages=61
# total=57
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=5700&name=&rows=100&page=5700&_=1539675850320
# total pages=61
# total=58
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=5800&name=&rows=100&page=5800&_=1539675850320
# total pages=61
# total=59
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=5900&name=&rows=100&page=5900&_=1539675850320
# total pages=61
# total=60
# url=http://www.bjrbj.gov.cn/integralpublic/settlePerson/settlePersonJson?sort=pxid&order=asc&limit=100&offset=6000&name=&rows=100&page=6000&_=1539675850320
# total pages=61
# total=61
